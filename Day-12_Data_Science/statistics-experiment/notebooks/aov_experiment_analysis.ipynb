# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("../data/raw/experiment_aov.csv")

df.head()

# %%
print("Shape:", df.shape)

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isna().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())

print("\nDuplicate customer IDs:")
print(df["customer_id"].duplicated().sum())

# %%
df["experiment_group"].value_counts()

# %%
df.groupby("experiment_group")["aov"].agg(
    ["count", "mean", "median", "std", "var", "min", "max"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.groupby("experiment_group")["aov"].agg(
#       2     ["count", "mean", "median", "std", "var", "min", "max"]
#       3 )
#
# NameError: name 'df' is not defined
